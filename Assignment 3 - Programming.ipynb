# %% [markdown]
# Assignment 3 - Programming By Jas Patil

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
gov = pd.read_csv('https://data.illinois.gov/dataset/2c47ae63-3be1-4985-904b-c5e5f4bf79ee/resource/aa78b062-07b2-40b4-8e24-e23778fa2f01/download/data.csv')

# %%
gov
# Out:
#            game_name    month  total_ticket_sales total_ticket_sales_count  \
# 0              Lotto  January            680904.0                  169,005
# 1    Lucky Day Lotto  January            519490.0                  406,786
# 2     Mega Millions   January            623048.0                  149,777
# 3             Pick 3  January            117236.0                    7,565
# 4     Pick3 Fireball  January             59059.0                    3,801
# ..               ...      ...                 ...                      ...
# 995           Pick 4  January             94370.5                  128,838
# 996   Pick4 Fireball  January             32219.5                   45,066
# 997        Powerball  January             26680.0                    6,664
# 998         EZ Match  January              1133.0                    1,133
# 999   Instant Rollup  January            100650.0              Not Tracked
#
#      year zip_code
# 0    2017   Online
# 1    2017   Online
# ...

# %%
gov["zip_code"].min()
# Out:
# '60002'

# %%
gov[gov["total_ticket_sales"] < 60000]
# Out:
#            game_name    month  total_ticket_sales total_ticket_sales_count  \
# 4     Pick3 Fireball  January             59059.0                    3,801
# 8           EZ Match  January              3344.0                    3,344
# 10             Lotto  January             22696.0                    6,883
# 11   Lucky Day Lotto  January             27941.0                   11,913
# 12    Mega Millions   January             21131.0                    7,693
# ..               ...      ...                 ...                      ...
# 992   Mega Millions   January             27513.0                    9,271
# 994   Pick3 Fireball  January             21003.0                   25,662
# 996   Pick4 Fireball  January             32219.5                   45,066
# 997        Powerball  January             26680.0                    6,664
# 998         EZ Match  January              1133.0                    1,133
#
#      year zip_code
# 4    2017   Online
# 8    2017    60002
# ...

# %%
gov1=gov.head(21)

# %%
with plt.style.context("ggplot"):
    gov1.plot.scatter(x='total_ticket_sales',y='zip_code', color = "red")

# %% [markdown]
# I used scatter plot to show relationship between two numeric variables Total ticket sales and zip code. Scatter plots generaaly denote patterns in data when are clustered, linear, non-linear, moderate or null. By looking at this graph we can say this data shows null relationship
